# %%
df=spark.read.table("api_formula1.default.circuits_table")

# %%
display(df)

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forName(spark, "api_formula1.default.circuits_table")
delta_table.update(
    condition = "latitude < 0",         
    set = { "latitude": "abs(latitude)" }
)

# %%
delta_table = DeltaTable.forName(spark, "api_formula1.default.circuits_table")

delta_table.delete("altitude == 0")
