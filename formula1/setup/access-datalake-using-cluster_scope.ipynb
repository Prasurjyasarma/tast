# %% [markdown]
# Access data lake using cluster scope credentials
# 1. Set the spark configg fs.azure.account.key in the cluster
# 2. List files from demo container
# 3. Read data from circuits.csv file

# %%
dbutils.fs.ls("abfss://demo@formula78dll.dfs.core.windows.net/")

# %%
display(spark.read.csv("abfss://demo@formula78dll.dfs.core.windows.net/circuits.csv"))
