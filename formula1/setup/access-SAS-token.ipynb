# %% [markdown]
# Access data lake using access keys
# 1. Set the spark SAS token
# 2. List files from demo container
# 3. Read data from circuits.csv file

# %%
spark.conf.set("fs.azure.account.auth.type.formula78dll.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.formula78dll.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.formula78dll.dfs.core.windows.net","sp=rl&st=2025-08-10T18:35:21Z&se=2025-08-11T02:50:21Z&spr=https&sv=2024-11-04&sr=c&sig=MSJqI2893SphmvTzfxy64I6%2FIpCk1g8VSo5kozJflFg%3D")

# %%
display(dbutils.fs.ls("abfss://demo@formula78dll.dfs.core.windows.net/"))

# %%
display(spark.read.csv("abfss://demo@formula78dll.dfs.core.windows.net/circuits.csv"))
